# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")
df
# Out:
#       OrderDetailsID   OrderID  ProductID  Quantity    Date  PriceApplied  \
# 0                  1    Ord-01          1         3  8/2/25        9000.0
# 1                  4    Ord-03          9         2  8/3/25        8500.0
# 2                  5    Ord-04          4         1  8/5/25        9000.0
# 3                  6    Ord-05          1         2  8/5/25        9000.0
# 4                  7    Ord-06          9         4  8/5/25        8500.0
# ...              ...       ...        ...       ...     ...           ...
# 3655            3690  Ord-2213         21        10  9/4/26       26000.0
# 3656            3691  Ord-2213         20         5  9/4/26       26000.0
# 3657            3692  Ord-2214          1         1  9/4/26       13500.0
# 3658            3693  Ord-2215          9         3  9/4/26       11500.0
# 3659            3694  Ord-2215         10         1  9/4/26       11500.0
#
#       CostApplied  Shop             ShopName          ProductName  ...  \
# ...

# %%
df.groupby("MonthName")["OrderID"].count()
# Out:
# MonthName
# April        286
# August       618
# December     234
# February     253
# January      122
# July         391
# June         285
# March        297
# May          392
# November     257
# October      276
# September    249
# Name: OrderID, dtype: int64

# %%
df.groupby('MonthName')['OrderID'].nunique()
# Out:
# MonthName
# April        182
# August       359
# December     151
# February     146
# January       77
# July         223
# June         172
# March        182
# May          227
# November     144
# October      168
# September    165
# Name: OrderID, dtype: int64
